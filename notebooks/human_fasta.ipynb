# %%
from Bio import SeqIO

def get_seq(seq_filename):
    record = SeqIO.read(seq_filename, "fasta")
    return str(record.seq)

# %%
long_seqs = []
with open("/home/gnye8/Desktop/PK_research/fasta_files/GRCh38_latest_genomic.fasta") as handle:
    for record in SeqIO.parse(handle, "fasta"):
        if len(record.seq) >= 30000:
            long_seqs.append(record.id)
        else:
            None
print(long_seqs)
# Out:
# ['NC_000001.11', 'NT_187361.1', 'NT_187362.1', 'NT_187363.1', 'NT_187364.1', 'NT_187365.1', 'NT_187366.1', 'NT_187367.1', 'NT_187368.1', 'NT_187369.1', 'NC_000002.12', 'NT_187370.1', 'NT_187371.1', 'NC_000003.12', 'NT_167215.1', 'NC_000004.12', 'NT_113793.3', 'NC_000005.10', 'NT_113948.1', 'NC_000006.12', 'NC_000007.14', 'NC_000008.11', 'NC_000009.12', 'NT_187372.1', 'NT_187373.1', 'NT_187374.1', 'NT_187375.1', 'NC_000010.11', 'NC_000011.10', 'NT_187376.1', 'NC_000012.12', 'NC_000013.11', 'NC_000014.9', 'NT_113796.3', 'NT_167219.1', 'NT_187377.1', 'NT_113888.1', 'NT_187378.1', 'NT_187379.1', 'NT_187380.1', 'NT_187381.1', 'NC_000015.10', 'NT_187382.1', 'NC_000016.10', 'NT_187383.1', 'NC_000017.11', 'NT_113930.2', 'NT_187384.1', 'NT_187385.1', 'NC_000018.10', 'NC_000019.10', 'NC_000020.11', 'NC_000021.9', 'NC_000022.11', 'NT_187386.1', 'NT_187387.1', 'NT_187388.1', 'NT_187389.1', 'NT_187390.1', 'NT_187391.1', 'NT_187392.1', 'NT_187393.1', 'NT_187394.1', 'NC_000023.11', 'NC_000024.10', 
# ...

# %%
with open("/home/gnye8/Desktop/PK_research/fasta_files/GRCh38_latest_genomic.fasta") as handle:
    for record in SeqIO.parse(handle, "fasta"):
        if record.id == 'NC_000001.11':
            full_seq = record.seq
        else:
            None

# %%
print(len(full_seq))
seq = full_seq[30000:60000]
print(len(seq))
print(seq)
# Out:
# 248956422
# 30000
# ...

# %%
seq = seq.lower()
print(seq)
# Out:
# ...
