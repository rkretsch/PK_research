# %%
import arnie
from arnie.utils import *
from arnie.mfe_bootstrap import mfe_bootstrap
from arnie.bpps import bpps
from arnie.mea.mea import MEA
from arnie.mea.mea_utils import *
from arnie.utils import _group_into_non_conflicting_bp
from arnie.pk_predictors import pk_predict_from_bpp
from Bio import SeqIO
import pandas as pd

def get_seq(seq_filename):
    record = SeqIO.read(seq_filename, "fasta")
    return str(record.seq)

def get_shape_data(filename):
    shape = []
    with open(filename) as f:
        for line in f:
            line = line.strip()
            shape.append(line)
            
    for i in range(len(shape)):
        shape[i] = (-1) if (shape[i] == 'nan') else (float(shape[i]))
        
    return shape

def get_sliding_windows(full_seq, shape, step, window):
    coords = list(range(0,len(full_seq)-window+1,step))
    seq_windows = []
    shape_windows = []
    for i in coords:
        new_seq_window = full_seq[i:i+window]
        seq_windows.append(new_seq_window)
        new_shape_window = shape[i:i+window]
        shape_windows.append(new_shape_window)
        
    return seq_windows, shape_windows, coords

def predict_pks(bpp, heuristic='threshknot', theta=0.3):
    structure = pk_predict_from_bpp(bpp, heuristic, theta)
    return structure

def get_bp_list(dotbracket):
    return convert_dotbracket_to_bp_list(dotbracket, allow_pseudoknots=True)

def get_groups(bp_list):
    return _group_into_non_conflicting_bp(bp_list)
    
def is_probable_PK(groups):
    likely_bp = 0
    for i in groups[1:]:
        if len(i) > 2:
            likely_bp += 1
    if likely_bp >= 2:
        return True
    else:
        return False
    
def get_shape_pseudoknots(seq_filename, shape_filename, step, window, num_bootstrap, theta=0.3):

    full_seq = get_seq(seq_filename)
    full_shape = get_shape_data(shape_filename)
    
    
    seq_windows, shape_windows, coords = get_sliding_windows(full_seq, full_shape, step, window)
    
    PK_hit_list = []
    fold_structures = []
    threshknot_structures = []
    PK_seqs = []
    for i,seq in enumerate(seq_windows):
        shape = shape_windows[i]
        mfe_struct, bpp = mfe_bootstrap(seq, num_bootstrap=num_bootstrap, shape_signal=shape, pk=False)
        threshknot_struct = predict_pks(bpp, heuristic='threshknot', theta=0.3)
        bp_list = convert_dotbracket_to_bp_list(threshknot_struct, allow_pseudoknots=True)
        groups = _group_into_non_conflicting_bp(bp_list)
        if is_PK(threshknot_struct):
            if is_probable_PK(groups):
                print('found one')
                PK_hit_list.append(i)
                fold_structures.append(mfe_struct)
                threshknot_structures.append(threshknot_struct)
                PK_seqs.append(seq)
        print('finished one seq')
        
    starts = []
    ends = []
    for i in PK_hit_list:
        start = coords[i]+1
        starts.append(start)
        end = coords[i]+window
        ends.append(end)
        
    PK_list = zip(starts, ends, PK_seqs, fold_structures, threshknot_structures)
    df = pd.DataFrame(PK_list, columns = ['start', 'end', 'sequence', 'fold_structure', 'threshknot_structure'])
    return df

# %%
shape_filenames = ['pyle_reactivity-Copy1.csv']
csv_filenames = ['pyle.csv']

for i, name in enumerate(shape_filenames): 
    csv_name = csv_filenames[i]
    df = get_shape_pseudoknots('/home/gnye8/Desktop/PK_research/SSRP_work/fasta_files/SARS_CoV2_reference.fasta', '/home/gnye8/Desktop/PK_research/SSRP_work/shape_data/{}'.format(name), 40, 120, 100)
    df.to_csv('/home/gnye8/Desktop/PK_research/pipeline_results/shape_directed_threshknot/{}'.format(csv_name))
# Out:
# Reached max iteration, stopping before converged.
# found one
# finished one seq
# finished one seq
# found one
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# WARNING some nucletotides found in more than 1 bp
# WARNING base 39 is in 2 basepairs [27, 39] [28, 39] THIS SHOULD BE FIXED. Removing [27, 39]
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# found one
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# Reached max iteration, stopping before converged.
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# found one
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# found one
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# Reached max iteration, stopping before converged.
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# found one
# finished one seq
# finished one seq
# finished one seq
# Reached max iteration, stopping before converged.
# WARNING some nucletotides found in more than 1 bp
# WARNING base 87 is in 2 basepairs [7, 87] [65, 87] THIS SHOULD BE FIXED. Removing [7, 87]
# found one
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# Reached max iteration, stopping before converged.
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# Reached max iteration, stopping before converged.
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# Reached max iteration, stopping before converged.
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# Reached max iteration, stopping before converged.
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# found one
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# WARNING some nucletotides found in more than 1 bp
# WARNING base 25 is in 2 basepairs [25, 39] [25, 73] THIS SHOULD BE FIXED. Removing [25, 73]
# finished one seq
# finished one seq
# finished one seq
# Reached max iteration, stopping before converged.
# WARNING some nucletotides found in more than 1 bp
# WARNING base 99 is in 2 basepairs [11, 99] [26, 99] THIS SHOULD BE FIXED. Removing [11, 99]
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# WARNING some nucletotides found in more than 1 bp
# WARNING base 64 is in 2 basepairs [64, 88] [64, 89] THIS SHOULD BE FIXED. Removing [64, 89]
# WARNING base 88 is in 2 basepairs [64, 88] [65, 88] THIS SHOULD BE FIXED. Removing [64, 88]
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# Reached max iteration, stopping before converged.
# finished one seq
# finished one seq
# found one
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# Reached max iteration, stopping before converged.
# found one
# finished one seq
# finished one seq
# Reached max iteration, stopping before converged.
# finished one seq
# found one
# finished one seq
# Reached max iteration, stopping before converged.
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# Reached max iteration, stopping before converged.
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# found one
# finished one seq
# found one
# finished one seq
# Reached max iteration, stopping before converged.
# finished one seq
# finished one seq
# Reached max iteration, stopping before converged.
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# found one
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# Reached max iteration, stopping before converged.
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# found one
# finished one seq
# finished one seq
# WARNING some nucletotides found in more than 1 bp
# WARNING base 69 is in 2 basepairs [69, 106] [69, 116] THIS SHOULD BE FIXED. Removing [69, 116]
# found one
# finished one seq
# Reached max iteration, stopping before converged.
# finished one seq
# finished one seq
# Reached max iteration, stopping before converged.
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# Reached max iteration, stopping before converged.
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# WARNING some nucletotides found in more than 1 bp
# WARNING base 106 is in 2 basepairs [68, 106] [106, 112] THIS SHOULD BE FIXED. Removing [68, 106]
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# WARNING some nucletotides found in more than 1 bp
# WARNING base 51 is in 2 basepairs [9, 51] [33, 51] THIS SHOULD BE FIXED. Removing [9, 51]
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# Reached max iteration, stopping before converged.
# finished one seq
# finished one seq
# finished one seq
# found one
# finished one seq
# finished one seq
# finished one seq
# found one
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# found one
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# WARNING some nucletotides found in more than 1 bp
# WARNING base 92 is in 2 basepairs [14, 92] [75, 92] THIS SHOULD BE FIXED. Removing [14, 92]
# found one
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# Reached max iteration, stopping before converged.
# WARNING some nucletotides found in more than 1 bp
# WARNING base 2 is in 2 basepairs [2, 36] [2, 93] THIS SHOULD BE FIXED. Removing [2, 93]
# WARNING base 3 is in 2 basepairs [3, 35] [3, 92] THIS SHOULD BE FIXED. Removing [3, 92]
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# found one
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# WARNING some nucletotides found in more than 1 bp
# WARNING base 81 is in 2 basepairs [81, 90] [81, 96] THIS SHOULD BE FIXED. Removing [81, 96]
# found one
# finished one seq
# found one
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# Reached max iteration, stopping before converged.
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# found one
# finished one seq
# finished one seq
# Reached max iteration, stopping before converged.
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# found one
# finished one seq
# found one
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# Reached max iteration, stopping before converged.
# finished one seq
# found one
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# WARNING some nucletotides found in more than 1 bp
# WARNING base 90 is in 2 basepairs [10, 90] [79, 90] THIS SHOULD BE FIXED. Removing [10, 90]
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# Reached max iteration, stopping before converged.
# found one
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# WARNING some nucletotides found in more than 1 bp
# WARNING base 29 is in 2 basepairs [29, 63] [29, 103] THIS SHOULD BE FIXED. Removing [29, 103]
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# found one
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# WARNING some nucletotides found in more than 1 bp
# WARNING base 72 is in 2 basepairs [34, 72] [72, 115] THIS SHOULD BE FIXED. Removing [72, 115]
# finished one seq
# finished one seq
# found one
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# Reached max iteration, stopping before converged.
# finished one seq
# found one
# finished one seq
# found one
# finished one seq
# Reached max iteration, stopping before converged.
# found one
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# Reached max iteration, stopping before converged.
# finished one seq
# Reached max iteration, stopping before converged.
# WARNING some nucletotides found in more than 1 bp
# WARNING base 77 is in 2 basepairs [15, 77] [77, 109] THIS SHOULD BE FIXED. Removing [15, 77]
# finished one seq
# found one
# finished one seq
# finished one seq
# WARNING some nucletotides found in more than 1 bp
# WARNING base 18 is in 2 basepairs [10, 18] [18, 23] THIS SHOULD BE FIXED. Removing [10, 18]
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# Reached max iteration, stopping before converged.
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# found one
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# WARNING some nucletotides found in more than 1 bp
# WARNING base 28 is in 2 basepairs [13, 28] [28, 95] THIS SHOULD BE FIXED. Removing [28, 95]
# WARNING base 27 is in 2 basepairs [14, 27] [27, 96] THIS SHOULD BE FIXED. Removing [27, 96]
# found one
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# found one
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# Reached max iteration, stopping before converged.
# finished one seq
# Reached max iteration, stopping before converged.
# found one
# finished one seq
# finished one seq
# finished one seq
# found one
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# found one
# finished one seq
# WARNING some nucletotides found in more than 1 bp
# WARNING base 96 is in 2 basepairs [38, 96] [48, 96] THIS SHOULD BE FIXED. Removing [38, 96]
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# WARNING some nucletotides found in more than 1 bp
# WARNING base 112 is in 2 basepairs [32, 112] [37, 112] THIS SHOULD BE FIXED. Removing [32, 112]
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# WARNING some nucletotides found in more than 1 bp
# WARNING base 81 is in 2 basepairs [16, 81] [81, 106] THIS SHOULD BE FIXED. Removing [16, 81]
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# Reached max iteration, stopping before converged.
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# Reached max iteration, stopping before converged.
# found one
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# WARNING some nucletotides found in more than 1 bp
# WARNING base 83 is in 2 basepairs [9, 83] [58, 83] THIS SHOULD BE FIXED. Removing [9, 83]
# WARNING base 80 is in 2 basepairs [12, 80] [61, 80] THIS SHOULD BE FIXED. Removing [12, 80]
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# WARNING some nucletotides found in more than 1 bp
# WARNING base 110 is in 2 basepairs [81, 110] [82, 110] THIS SHOULD BE FIXED. Removing [81, 110]
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# found one
# finished one seq
# finished one seq
# finished one seq
# WARNING some nucletotides found in more than 1 bp
# WARNING base 26 is in 2 basepairs [26, 58] [26, 116] THIS SHOULD BE FIXED. Removing [26, 116]
# finished one seq
# finished one seq
# finished one seq
# Reached max iteration, stopping before converged.
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# found one
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# WARNING some nucletotides found in more than 1 bp
# WARNING base 13 is in 2 basepairs [13, 26] [13, 29] THIS SHOULD BE FIXED. Removing [13, 29]
# finished one seq
# finished one seq
# finished one seq
# Reached max iteration, stopping before converged.
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# Reached max iteration, stopping before converged.
# found one
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# Reached max iteration, stopping before converged.
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# Reached max iteration, stopping before converged.
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# Reached max iteration, stopping before converged.
# finished one seq
