# %%
import arnie
from arnie.utils import *
from arnie.mfe_bootstrap import mfe_bootstrap
from arnie.bpps import bpps
from arnie.mea.mea import MEA
from arnie.mea.mea_utils import *
from arnie.utils import _group_into_non_conflicting_bp
from arnie.pk_predictors import pk_predict_from_bpp
from Bio import SeqIO
import pandas as pd

def get_seq(seq_filename):
    record = SeqIO.read(seq_filename, "fasta")
    return str(record.seq)

def get_shape_data(filename):
    shape = []
    with open(filename) as f:
        for line in f:
            line = line.strip()
            shape.append(line)
            
    for i in range(len(shape)):
        shape[i] = (-1) if (shape[i] == 'nan') else (float(shape[i]))
        
    return shape

def get_sliding_windows(full_seq, shape, step, window):
    coords = list(range(0,len(full_seq)-window+1,step))
    seq_windows = []
    shape_windows = []
    for i in coords:
        new_seq_window = full_seq[i:i+window]
        seq_windows.append(new_seq_window)
        new_shape_window = shape[i:i+window]
        shape_windows.append(new_shape_window)
        
    return seq_windows, shape_windows, coords

def predict_pks(bpp, heuristic='threshknot', theta=0.3):
    structure = pk_predict_from_bpp(bpp, heuristic, theta)
    return structure

def get_bp_list(dotbracket):
    return convert_dotbracket_to_bp_list(dotbracket, allow_pseudoknots=True)

def get_groups(bp_list):
    return _group_into_non_conflicting_bp(bp_list)
    
def is_probable_PK(groups):
    likely_bp = 0
    for i in groups[1:]:
        if len(i) > 2:
            likely_bp += 1
    if likely_bp >= 2:
        return True
    else:
        return False
    
def get_shape_pseudoknots(seq_filename, shape_filename, step, window, num_bootstrap, theta=0.3):

    full_seq = get_seq(seq_filename)
    full_shape = get_shape_data(shape_filename)
    
    
    seq_windows, shape_windows, coords = get_sliding_windows(full_seq, full_shape, step, window)
    
    PK_hit_list = []
    fold_structures = []
    threshknot_structures = []
    PK_seqs = []
    for i,seq in enumerate(seq_windows):
        shape = shape_windows[i]
        mfe_struct, bpp = mfe_bootstrap(seq, num_bootstrap=num_bootstrap, shape_signal=shape, pk=False)
        threshknot_struct = predict_pks(bpp, heuristic='threshknot', theta=0.3)
        bp_list = convert_dotbracket_to_bp_list(threshknot_struct, allow_pseudoknots=True)
        groups = _group_into_non_conflicting_bp(bp_list)
        if is_PK(threshknot_struct):
            if is_probable_PK(groups):
                print('found one')
                PK_hit_list.append(i)
                fold_structures.append(mfe_struct)
                threshknot_structures.append(threshknot_struct)
                PK_seqs.append(seq)
        print('finished one seq')
        
    starts = []
    ends = []
    for i in PK_hit_list:
        start = coords[i]+1
        starts.append(start)
        end = coords[i]+window
        ends.append(end)
        
    PK_list = zip(starts, ends, PK_seqs, fold_structures, threshknot_structures)
    df = pd.DataFrame(PK_list, columns = ['start', 'end', 'sequence', 'fold_structure', 'threshknot_structure'])
    return df

# %%
shape_filenames = ['pyle_reactivity-Copy1.csv']
csv_filenames = ['pyle.csv']

for i, name in enumerate(shape_filenames): 
    csv_name = csv_filenames[i]
    df = get_shape_pseudoknots('/home/gnye8/Desktop/PK_research/SSRP_work/fasta_files/SARS_CoV2_reference.fasta', '/home/gnye8/Desktop/PK_research/SSRP_work/shape_data/{}'.format(name), 40, 120, 100)
    df.to_csv('/home/gnye8/Desktop/PK_research/pipeline_results/shape_directed_threshknot/{}'.format(csv_name))
# Out:
# Reached max iteration, stopping before converged.
# found one
# finished one seq
# finished one seq
# Reached max iteration, stopping before converged.
# WARNING some nucletotides found in more than 1 bp
# WARNING base 108 is in 2 basepairs [108, 112] [108, 119] THIS SHOULD BE FIXED. Removing [108, 119]
# found one
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# WARNING some nucletotides found in more than 1 bp
# WARNING base 79 is in 2 basepairs [79, 100] [79, 102] THIS SHOULD BE FIXED. Removing [79, 102]
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# Reached max iteration, stopping before converged.
# finished one seq
# finished one seq
# WARNING some nucletotides found in more than 1 bp
# WARNING base 113 is in 2 basepairs [34, 113] [62, 113] THIS SHOULD BE FIXED. Removing [34, 113]
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# WARNING some nucletotides found in more than 1 bp
# WARNING base 10 is in 2 basepairs [10, 25] [10, 119] THIS SHOULD BE FIXED. Removing [10, 119]
# WARNING base 11 is in 2 basepairs [11, 24] [11, 118] THIS SHOULD BE FIXED. Removing [11, 118]
# found one
# finished one seq
# WARNING some nucletotides found in more than 1 bp
# WARNING base 97 is in 2 basepairs [97, 108] [97, 117] THIS SHOULD BE FIXED. Removing [97, 117]
# WARNING base 98 is in 2 basepairs [98, 107] [98, 116] THIS SHOULD BE FIXED. Removing [98, 116]
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# Reached max iteration, stopping before converged.
# finished one seq
# Reached max iteration, stopping before converged.
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# Reached max iteration, stopping before converged.
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# found one
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# Reached max iteration, stopping before converged.
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# WARNING some nucletotides found in more than 1 bp
# WARNING base 21 is in 2 basepairs [21, 53] [21, 58] THIS SHOULD BE FIXED. Removing [21, 58]
# WARNING base 53 is in 2 basepairs [21, 53] [26, 53] THIS SHOULD BE FIXED. Removing [21, 53]
# WARNING base 28 is in 2 basepairs [28, 45] [28, 51] THIS SHOULD BE FIXED. Removing [28, 51]
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# WARNING some nucletotides found in more than 1 bp
# WARNING base 93 is in 2 basepairs [87, 93] [93, 111] THIS SHOULD BE FIXED. Removing [93, 111]
# finished one seq
# finished one seq
# finished one seq
# found one
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# found one
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# Reached max iteration, stopping before converged.
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# Reached max iteration, stopping before converged.
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# found one
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# found one
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# Reached max iteration, stopping before converged.
# WARNING some nucletotides found in more than 1 bp
# WARNING base 103 is in 2 basepairs [7, 103] [22, 103] THIS SHOULD BE FIXED. Removing [7, 103]
# WARNING base 101 is in 2 basepairs [9, 101] [24, 101] THIS SHOULD BE FIXED. Removing [9, 101]
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# found one
# finished one seq
# Reached max iteration, stopping before converged.
# finished one seq
# finished one seq
# Reached max iteration, stopping before converged.
# finished one seq
# finished one seq
# Reached max iteration, stopping before converged.
# finished one seq
# finished one seq
# found one
# finished one seq
# finished one seq
# Reached max iteration, stopping before converged.
# finished one seq
# finished one seq
# Reached max iteration, stopping before converged.
# found one
# finished one seq
# finished one seq
# WARNING some nucletotides found in more than 1 bp
# WARNING base 41 is in 2 basepairs [10, 41] [41, 115] THIS SHOULD BE FIXED. Removing [41, 115]
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# Reached max iteration, stopping before converged.
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# Reached max iteration, stopping before converged.
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# Reached max iteration, stopping before converged.
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# found one
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# WARNING some nucletotides found in more than 1 bp
# WARNING base 95 is in 2 basepairs [77, 95] [78, 95] THIS SHOULD BE FIXED. Removing [77, 95]
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# Reached max iteration, stopping before converged.
# finished one seq
# finished one seq
# Reached max iteration, stopping before converged.
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# Reached max iteration, stopping before converged.
# finished one seq
# finished one seq
# Reached max iteration, stopping before converged.
# found one
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# WARNING some nucletotides found in more than 1 bp
# WARNING base 8 is in 2 basepairs [8, 20] [8, 25] THIS SHOULD BE FIXED. Removing [8, 25]
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# found one
# finished one seq
# found one
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# WARNING some nucletotides found in more than 1 bp
# WARNING base 13 is in 2 basepairs [13, 51] [13, 114] THIS SHOULD BE FIXED. Removing [13, 114]
# finished one seq
# WARNING some nucletotides found in more than 1 bp
# WARNING base 100 is in 2 basepairs [54, 100] [55, 100] THIS SHOULD BE FIXED. Removing [54, 100]
# finished one seq
# Reached max iteration, stopping before converged.
# found one
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# WARNING some nucletotides found in more than 1 bp
# WARNING base 44 is in 2 basepairs [12, 44] [44, 73] THIS SHOULD BE FIXED. Removing [12, 44]
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# found one
# finished one seq
# Reached max iteration, stopping before converged.
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# found one
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# found one
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# found one
# finished one seq
# finished one seq
# Reached max iteration, stopping before converged.
# finished one seq
# finished one seq
# Reached max iteration, stopping before converged.
# found one
# finished one seq
# finished one seq
# finished one seq
# found one
# finished one seq
# found one
# finished one seq
# WARNING some nucletotides found in more than 1 bp
# WARNING base 80 is in 2 basepairs [80, 98] [80, 105] THIS SHOULD BE FIXED. Removing [80, 105]
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# WARNING some nucletotides found in more than 1 bp
# WARNING base 96 is in 2 basepairs [1, 96] [96, 108] THIS SHOULD BE FIXED. Removing [1, 96]
# WARNING base 93 is in 2 basepairs [4, 93] [93, 112] THIS SHOULD BE FIXED. Removing [4, 93]
# finished one seq
# finished one seq
# finished one seq
# found one
# finished one seq
# finished one seq
# finished one seq
# found one
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# Reached max iteration, stopping before converged.
# WARNING some nucletotides found in more than 1 bp
# WARNING base 16 is in 2 basepairs [16, 21] [16, 24] THIS SHOULD BE FIXED. Removing [16, 24]
# found one
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# Reached max iteration, stopping before converged.
# found one
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# found one
# finished one seq
# WARNING some nucletotides found in more than 1 bp
# WARNING base 67 is in 2 basepairs [67, 90] [67, 104] THIS SHOULD BE FIXED. Removing [67, 104]
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# Reached max iteration, stopping before converged.
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# WARNING some nucletotides found in more than 1 bp
# WARNING base 71 is in 2 basepairs [50, 71] [53, 71] THIS SHOULD BE FIXED. Removing [50, 71]
# WARNING base 69 is in 2 basepairs [52, 69] [55, 69] THIS SHOULD BE FIXED. Removing [52, 69]
# WARNING base 54 is in 2 basepairs [54, 67] [54, 70] THIS SHOULD BE FIXED. Removing [54, 70]
# WARNING base 67 is in 2 basepairs [54, 67] [57, 67] THIS SHOULD BE FIXED. Removing [54, 67]
# finished one seq
# finished one seq
# finished one seq
# Reached max iteration, stopping before converged.
# finished one seq
# Reached max iteration, stopping before converged.
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# WARNING some nucletotides found in more than 1 bp
# WARNING base 31 is in 2 basepairs [12, 31] [19, 31] THIS SHOULD BE FIXED. Removing [12, 31]
# found one
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# Reached max iteration, stopping before converged.
# finished one seq
# finished one seq
# finished one seq
# Reached max iteration, stopping before converged.
# found one
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# Reached max iteration, stopping before converged.
# finished one seq
# found one
# finished one seq
# Reached max iteration, stopping before converged.
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# Reached max iteration, stopping before converged.
# finished one seq
# found one
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# Reached max iteration, stopping before converged.
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# Reached max iteration, stopping before converged.
# finished one seq
# WARNING some nucletotides found in more than 1 bp
# WARNING base 76 is in 2 basepairs [76, 96] [76, 97] THIS SHOULD BE FIXED. Removing [76, 97]
# WARNING base 96 is in 2 basepairs [76, 96] [77, 96] THIS SHOULD BE FIXED. Removing [76, 96]
# finished one seq
# WARNING some nucletotides found in more than 1 bp
# WARNING base 87 is in 2 basepairs [76, 87] [77, 87] THIS SHOULD BE FIXED. Removing [76, 87]
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# found one
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# Reached max iteration, stopping before converged.
# finished one seq
# found one
# finished one seq
# found one
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# found one
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# WARNING some nucletotides found in more than 1 bp
# WARNING base 23 is in 2 basepairs [23, 95] [23, 106] THIS SHOULD BE FIXED. Removing [23, 106]
# WARNING base 24 is in 2 basepairs [24, 94] [24, 105] THIS SHOULD BE FIXED. Removing [24, 105]
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# Reached max iteration, stopping before converged.
# finished one seq
# Reached max iteration, stopping before converged.
# found one
# finished one seq
# finished one seq
# finished one seq
# found one
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# found one
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# Reached max iteration, stopping before converged.
# finished one seq
# Reached max iteration, stopping before converged.
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# Reached max iteration, stopping before converged.
# finished one seq
# finished one seq
# finished one seq
# WARNING some nucletotides found in more than 1 bp
# WARNING base 113 is in 2 basepairs [32, 113] [34, 113] THIS SHOULD BE FIXED. Removing [32, 113]
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# WARNING some nucletotides found in more than 1 bp
# WARNING base 97 is in 2 basepairs [79, 97] [86, 97] THIS SHOULD BE FIXED. Removing [79, 97]
# WARNING base 95 is in 2 basepairs [81, 95] [88, 95] THIS SHOULD BE FIXED. Removing [81, 95]
# finished one seq
# finished one seq
# found one
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# Reached max iteration, stopping before converged.
# finished one seq
# finished one seq
# found one
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# Reached max iteration, stopping before converged.
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# WARNING some nucletotides found in more than 1 bp
# WARNING base 43 is in 2 basepairs [4, 43] [37, 43] THIS SHOULD BE FIXED. Removing [4, 43]
# WARNING base 38 is in 2 basepairs [9, 38] [38, 42] THIS SHOULD BE FIXED. Removing [9, 38]
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# Reached max iteration, stopping before converged.
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# Reached max iteration, stopping before converged.
# finished one seq
# finished one seq
# finished one seq
# found one
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# found one
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# Reached max iteration, stopping before converged.
# WARNING some nucletotides found in more than 1 bp
# WARNING base 89 is in 2 basepairs [80, 89] [82, 89] THIS SHOULD BE FIXED. Removing [80, 89]
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# WARNING some nucletotides found in more than 1 bp
# WARNING base 102 is in 2 basepairs [102, 111] [102, 114] THIS SHOULD BE FIXED. Removing [102, 114]
# WARNING base 111 is in 2 basepairs [102, 111] [105, 111] THIS SHOULD BE FIXED. Removing [102, 111]
# WARNING base 104 is in 2 basepairs [104, 109] [104, 112] THIS SHOULD BE FIXED. Removing [104, 112]
# finished one seq
# Reached max iteration, stopping before converged.
# finished one seq
# WARNING some nucletotides found in more than 1 bp
# WARNING base 24 is in 2 basepairs [13, 24] [17, 24] THIS SHOULD BE FIXED. Removing [13, 24]
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# found one
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# found one
# finished one seq
# finished one seq
# finished one seq
# WARNING some nucletotides found in more than 1 bp
# WARNING base 41 is in 2 basepairs [15, 41] [19, 41] THIS SHOULD BE FIXED. Removing [15, 41]
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# Reached max iteration, stopping before converged.
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# found one
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# Reached max iteration, stopping before converged.
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
# finished one seq
